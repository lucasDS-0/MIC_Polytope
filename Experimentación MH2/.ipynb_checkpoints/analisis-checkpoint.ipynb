# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_resultados = pd.read_csv("resultados/resultados-impactoVsIteracionConAzar.csv");
df_resultados
# Out:
#      metodo   n    mG      mH  iteracion  impacto  tipoVecindad
# 0       MH2  68  1204  911\n1          0     61.0             0
# 1       MH2  68  1204  911\n1          1     63.0             0
# 2       MH2  68  1204  911\n1          2     65.0             0
# 3       MH2  68  1204  911\n1          3     67.0             0
# 4       MH2  68  1204  911\n1          4     69.0             0
# ...     ...  ..   ...     ...        ...      ...           ...
# 9245    MH2  68  1204  911\n1       4620     93.0             2
# 9246    MH2  68  1204  911\n1       4621     93.0             2
# 9247    MH2  68  1204  911\n1       4622     93.0             2
# 9248    MH2  68  1204  911\n1       4623     93.0             2
# 9249    MH2  68  1204  911\n1       4624     93.0             2
#
# [9250 rows x 7 columns]

# %%
vecindad_size = df_resultados.copy();
plt.figure(figsize=(16, 6))
fig = sns.lineplot(data=vecindad_size, x='iteracion', y='impacto',hue='tipoVecindad', palette='bright',ci=None)
plt.show(fig)
plt.savefig("graficos/vecindadsizeImpactoVsIteraciones68.svg")

# %%
vecindad_size = df_resultados.copy();
plt.figure(figsize=(16, 6))
fig = sns.lineplot(data=vecindad_size, x='iteracion', y='impacto',hue='tipoVecindad',palette='bright',ci=None)
plt.show(fig)
plt.savefig("graficos/vecindadsizeImpactoVsIteraciones60.svg")

# %%
vecindad_size = df_resultados.copy();
plt.figure(figsize=(16, 6))
fig = sns.lineplot(data=vecindad_size, x='iteracion', y='impacto',hue='tipoVecindad',palette='bright',ci=None)
plt.show(fig)
plt.savefig("graficos/vecindadsizeImpactoVsIteraciones60.svg")

# %%
df_resultados = pd.read_csv("resultados/resultados-impactoVsIteracionConAzar.csv");
df_resultados
# Out:
#      metodo   n  mG      mH  iteracion  impacto  tipoVecindad
# 0       MH2  60  12  701\n2          0    365.0             0
# 1       MH2  60  12  701\n2          1    377.0             0
# 2       MH2  60  12  701\n2          2    389.0             0
# 3       MH2  60  12  701\n2          3    399.0             0
# 4       MH2  60  12  701\n2          4    411.0             0
# ...     ...  ..  ..     ...        ...      ...           ...
# 1796    MH2  60  12  701\n2       1796    516.0             0
# 1797    MH2  60  12  701\n2       1797    519.0             0
# 1798    MH2  60  12  701\n2       1798    519.0             0
# 1799    MH2  60  12  701\n2       1799    517.0             0
# 1800    MH2  60  12  701\n2       1800    516.0             0
#
# [1801 rows x 7 columns]

# %%
vecindad_size = df_resultados.copy();
plt.figure(figsize=(16, 6))
fig = sns.lineplot(data=vecindad_size, x='iteracion', y='impacto',palette='bright',ci=None)
plt.show(fig)
plt.savefig("graficos/vecindadsizeImpactoVsIteraciones60VecindadNoRandom.svg")

# %%
df_resultados = pd.read_csv("resultados/resultados-mem-size-ralo.csv");
df_resultados
# Out:
#     metodo   n  mG      mH  impacto     tiempo     error  mem-size-ralo  \
# 0      MH2  34  24   294.0    158.0   22.45610  0.462585             25
# 1      MH2  25  13    53.0     33.0    2.77393  0.377358             25
# 2      MH2  39  20   133.0     80.0   14.46610  0.398496             25
# 3      MH2  60  12   698.0    519.0  124.42800  0.256447             25
# 4      MH2  51  17   143.0    106.0   29.17090  0.258741             25
# ..     ...  ..  ..     ...      ...        ...       ...            ...
# 145    MH2  50  29   109.0     66.0   21.97830  0.394495             75
# 146    MH2  37  31   238.0    118.0   14.75010  0.504202             75
# 147    MH2  29  27   115.0     57.0    5.19229  0.504348             75
# 148    MH2  68  25   900.0    570.0  177.11700  0.366667             75
# 149    MH2  64  40  1128.0    596.0  152.59500  0.471631             75
#
#      rango-n
# 0         30
# 1         20
# 2         30
# 3         60
# 4         50
# ..       ...
# ...

# %%
mem_size = df_resultados.copy();
plt.figure(figsize=(10, 7))
sns.boxplot(x="rango-n", y="error",
            hue="mem-size-ralo", palette=["r", "g","c"],
            data=mem_size)

plt.savefig("graficos/mem-size-ralo.svg")

# %%
mem_size = df_resultados.copy();
plt.figure(figsize=(10, 7))
sns.lineplot(x="rango-n", y="tiempo",
            hue="mem-size-ralo", palette=["r", "g","b"],
            data=mem_size)

plt.savefig("graficos/mem-size-ralo-tiempo.svg")

# %%
df_resultados = pd.read_csv("resultados/resultados-mem-size-denso.csv");
df_resultados
# Out:
#     metodo   n    mG    mH  impacto     tiempo     error  mem-size-denso  \
# 0      MH2  20    73    90     21.0    13.1706  0.766667              25
# 1      MH2  31   206   109     24.0    54.1412  0.779817              25
# 2      MH2  63  1141    39     12.0   193.2690  0.692308              25
# 3      MH2  34   234   309     47.0   183.4910  0.847896              25
# 4      MH2  42   429   521     58.0   611.4510  0.888676              25
# ..     ...  ..   ...   ...      ...        ...       ...             ...
# 145    MH2  47   466   558     67.6   357.2870  0.878853              75
# 146    MH2  40   443   451     40.0   184.9400  0.911308              75
# 147    MH2  59   831  1002     90.0  1011.2000  0.910180              75
# 148    MH2  68  1204   911     80.0  1360.0300  0.912184              75
# 149    MH2  32   271   267     29.0    48.8892  0.891386              75
#
#      rango-n
# 0         20
# 1         30
# 2         60
# 3         30
# 4         40
# ...

# %%
mem_size = df_resultados.copy();
plt.figure(figsize=(10,7 ))
sns.boxplot(x="rango-n", y="error",
            hue="mem-size-denso", palette=["r", "g","c"],
            data=mem_size)

plt.savefig("graficos/mem-size-denso.svg")

# %%
mem_size = df_resultados.copy();
plt.figure(figsize=(10,7 ))
sns.lineplot(x="rango-n", y="tiempo",
            hue="mem-size-denso", palette=["r", "g","b"],
            data=mem_size)


plt.savefig("graficos/mem-size-denso-tiempo.svg")

# %%
df_resultados = pd.read_csv("resultados/resultados-cant-colores-ralo.csv");
df_resultados
# Out:
#     metodo   n  mG    mH  impacto     tiempo     error  cant-colores-ralo  \
# 0      MH2  34  24   309    161.0   16.47930  0.452381                  0
# 1      MH2  25  13    55     33.0    2.08818  0.377358                  0
# 2      MH2  39  20   137     80.0   10.85600  0.398496                  0
# 3      MH2  60  12   701    519.0   98.04260  0.256447                  0
# 4      MH2  51  17   146    103.0   19.19730  0.279720                  0
# ..     ...  ..  ..   ...      ...        ...       ...                ...
# 145    MH2  50  29   114     70.0   17.97670  0.357798                  2
# 146    MH2  37  31   249    123.0   17.77790  0.483193                  2
# 147    MH2  29  27   127     59.0    9.30457  0.486957                  2
# 148    MH2  68  25   911    561.2  223.08200  0.376444                  2
# 149    MH2  64  40  1153    614.0  209.51300  0.455674                  2
#
#      rango-n
# 0         30
# 1         20
# 2         30
# 3         60
# ...

# %%
mem_size = df_resultados.copy();
plt.figure(figsize=(10,7 ))
sns.boxplot(x="rango-n", y="error",
            hue="cant-colores-ralo", palette=["r", "g","c"],
            data=mem_size)

plt.savefig("graficos/cant-colores-ralo.svg")

# %%
df_resultados = pd.read_csv("resultados/resultados-cant-colores-denso.csv");
df_resultados
# Out:
#     metodo   n    mG    mH  impacto     tiempo     error  cant-colores-denso  \
# 0      MH2  20    73    90     21.0    1.91120  0.553191                   0
# 1      MH2  31   206   109     24.0    6.12846  0.606557                   0
# 2      MH2  63  1141    39     12.0   22.30010  0.142857                   0
# 3      MH2  34   234   309     42.0   16.15270  0.751479                   0
# 4      MH2  42   429   521     57.0   36.61020  0.768293                   0
# ..     ...  ..   ...   ...      ...        ...       ...                 ...
# 145    MH2  47   466   558     73.0   59.40540  0.765273                   2
# 146    MH2  40   443   451     41.0   35.86470  0.757396                   2
# 147    MH2  59   831  1002     98.4  158.56300  0.808187                   2
# 148    MH2  68  1204   911     89.6  183.24700  0.787678                   2
# 149    MH2  32   271   267     31.0   13.50370  0.683673                   2
#
#      rango-n
# 0         20
# 1         30
# ...

# %%
mem_size = df_resultados.copy();
plt.figure(figsize=(10, 7))
sns.boxplot(x="rango-n", y="error",
            hue="cant-colores-denso", palette=["r", "g","c"],
            data=mem_size)

plt.savefig("graficos/cant-colores-denso.svg")

# %%
df_resultados = pd.read_csv("resultados/resultados-tipo-vecindad-denso-pocos-colores.csv");
df_resultados
# Out:
#     metodo   n    mG    mH  impacto     tiempo     error  \
# 0      MH2  20    73    90     21.0    2.23097  0.553191
# 1      MH2  31   206   109     24.0    6.10372  0.606557
# 2      MH2  63  1141    39     12.0   22.22390  0.142857
# 3      MH2  34   234   309     40.0   16.25650  0.763314
# 4      MH2  42   429   521     57.0   38.11420  0.768293
# ..     ...  ..   ...   ...      ...        ...       ...
# 195    MH2  47   466   558     75.0   86.44960  0.758842
# 196    MH2  40   443   451     41.0   59.27270  0.757396
# 197    MH2  59   831  1002    103.6  247.82300  0.798051
# 198    MH2  68  1204   911     97.4  483.06300  0.769194
# 199    MH2  32   271   267     31.0   25.15030  0.683673
#
#      tipo-vecindad-denso-pocos-colores  rango-n
# 0                                    0       20
# 1                                    0       30
# 2                                    0       60
# 3                                    0       30
# ...

# %%
mem_size = df_resultados.copy();
plt.figure(figsize=(10, 7))
sns.boxplot(x="rango-n", y="error",
            hue="tipo-vecindad-denso-pocos-colores", palette=["r", "g","c","y"],
            data=mem_size)

plt.savefig("graficos/tipo-vecindad-denso-pocos-colores.svg")

# %%
df_resultados = pd.read_csv("resultados/resultados-tipo-vecindad-ralo-pocos-colores.csv");
df_resultados
# Out:
#     metodo   n  mG    mH  impacto     tiempo     error  \
# 0      MH2  34  24   309    157.0   16.73900  0.465986
# 1      MH2  25  13    55     33.0    2.27354  0.377358
# 2      MH2  39  20   137     77.0   10.84520  0.421053
# 3      MH2  60  12   701    519.0   98.00830  0.256447
# 4      MH2  51  17   146    103.0   19.13350  0.279720
# ..     ...  ..  ..   ...      ...        ...       ...
# 195    MH2  50  29   114     76.0   40.82300  0.302752
# 196    MH2  37  31   249    128.0   30.59380  0.462185
# 197    MH2  29  27   127     62.0   12.83560  0.460870
# 198    MH2  68  25   911    565.0  499.44800  0.372222
# 199    MH2  64  40  1153    614.2  899.56200  0.455496
#
#      tipo-vecindad-ralo-pocos-colores  rango-n
# 0                                   0       30
# 1                                   0       20
# 2                                   0       30
# 3                                   0       60
# 4                                   0       50
# ...

# %%
mem_size = df_resultados.copy();
plt.figure(figsize=(10, 7))
sns.boxplot(x="rango-n", y="error",
            hue="tipo-vecindad-ralo-pocos-colores", palette=["r", "g","c","y"],
            data=mem_size)

plt.savefig("graficos/tipo-vecindad-ralo-pocos-colores.svg")

# %%
df_resultados = pd.read_csv("resultados/resultados-vecindad-size-denso.csv");
df_resultados
# Out:
#     metodo   n    mG    mH  impacto      tiempo     error  \
# 0      MH2  20    73    90     21.0     4.80474  0.553191
# 1      MH2  31   206   109     24.0    29.12250  0.606557
# 2      MH2  63  1141    39     12.0   155.94100  0.142857
# 3      MH2  34   234   309     47.0    39.53430  0.721893
# 4      MH2  42   429   521     57.4    88.73670  0.766667
# ..     ...  ..   ...   ...      ...         ...       ...
# 145    MH2  47   466   558     73.0   685.24000  0.765273
# 146    MH2  40   443   451     43.0   376.29600  0.745562
# 147    MH2  59   831  1002    100.0  2147.92000  0.805068
# 148    MH2  68  1204   911     89.0  3230.42000  0.789100
# 149    MH2  32   271   267     31.0   109.29700  0.683673
#
#      vecindad-size-denso  rango-n
# 0                      0       20
# 1                      0       30
# 2                      0       60
# 3                      0       30
# 4                      0       40
# ..                   ...      ...
# ...

# %%
mem_size = df_resultados.copy();
plt.figure(figsize=(10, 7))
sns.boxplot(x="rango-n", y="error",
            hue="vecindad-size-denso", palette=["r", "g","c","y"],
            data=mem_size)

plt.savefig("graficos/vecindad-size-denso.svg")

# %%
df_resultados = pd.read_csv("resultados/resultados-vecindad-size-ralo.csv");
df_resultados
# Out:
#     metodo   n  mG    mH  impacto      tiempo     error  vecindad-size-ralo  \
# 0      MH2  34  24   309    158.0    47.24140  0.462585                   0
# 1      MH2  25  13    55     38.0     4.68685  0.283019                   0
# 2      MH2  39  20   137     90.0    23.47970  0.323308                   0
# 3      MH2  60  12   701    531.4   375.61000  0.238682                   0
# 4      MH2  51  17   146    104.6    88.90220  0.268531                   0
# ..     ...  ..  ..   ...      ...         ...       ...                 ...
# 145    MH2  50  29   114     75.0   201.07400  0.311927                   2
# 146    MH2  37  31   249    131.0   169.40100  0.449580                   2
# 147    MH2  29  27   127     61.0    47.26150  0.469565                   2
# 148    MH2  68  25   911    586.0  3873.61000  0.348889                   2
# 149    MH2  64  40  1153    604.0  4456.83000  0.464539                   2
#
#      rango-n
# 0         30
# 1         20
# ...

# %%
mem_size = df_resultados.copy();
plt.figure(figsize=(10, 7))
sns.boxplot(x="rango-n", y="error",
            hue="vecindad-size-ralo", palette=["r", "g","c","y"],
            data=mem_size)

plt.savefig("graficos/vecindad-size-ralo.svg")

# %%
df_resultados = pd.read_csv("resultados/resultados-vecindad-size-ralo-2.csv");
df_resultados
# Out:
#     metodo   n  mG    mH  impacto      tiempo     error  vecindad-size  \
# 0      MH2  34  24   309    157.0    4.012460  0.465986              1
# 1      MH2  25  13    55     37.0    0.543143  0.301887              1
# 2      MH2  39  20   137     83.0    2.215380  0.375940              1
# 3      MH2  60  12   701    528.0   25.552000  0.243553              1
# 4      MH2  51  17   146    104.0    4.721890  0.272727              1
# ..     ...  ..  ..   ...      ...         ...       ...            ...
# 145    MH2  50  29   114     66.0   16.204200  0.394495             -1
# 146    MH2  37  31   249    119.0   16.839300  0.500000             -1
# 147    MH2  29  27   127     54.0    4.977490  0.530435             -1
# 148    MH2  68  25   911    565.0  286.956000  0.372222             -1
# 149    MH2  64  40  1153    603.0  331.623000  0.465426             -1
#
#      rango-n
# 0         30
# 1         20
# 2         30
# 3         60
# 4         50
# ..       ...
# ...

# %%
mem_size = df_resultados.copy();
plt.figure(figsize=(10, 7))
sns.boxplot(x="rango-n", y="error",
            hue="vecindad-size", palette=["r", "g","c","y"],
            data=mem_size)

plt.savefig("graficos/vecindad-size-ralo-2.svg")

# %%
df_resultados = pd.read_csv("resultados/resultados-vecindad-size-ralo-2.csv");
df_resultados
# Out:
#     metodo   n  mG    mH  impacto       tiempo     error  vecindad-size  \
# 0      MH2  34  24   309    159.0    101.21300  0.459184              1
# 1      MH2  25  13    55     38.0      8.95602  0.283019              1
# 2      MH2  39  20   137     86.0     64.51880  0.353383              1
# 3      MH2  60  12   701    530.0   1041.87000  0.240688              1
# 4      MH2  51  17   146    104.0    176.97800  0.272727              1
# ..     ...  ..  ..   ...      ...          ...       ...            ...
# 145    MH2  50  29   114     77.0    528.08100  0.293578             -1
# 146    MH2  37  31   249    125.0    399.57500  0.474790             -1
# 147    MH2  29  27   127     62.0     91.43760  0.460870             -1
# 148    MH2  68  25   911    589.0  11856.40000  0.345556             -1
# 149    MH2  64  40  1153    616.0  12873.90000  0.453901             -1
#
#      rango-n
# 0         30
# 1         20
# 2         30
# 3         60
# 4         50
# ..       ...
# ...

# %%
mem_size = df_resultados.copy();
plt.figure(figsize=(10, 7))
sns.boxplot(x="rango-n", y="error",
            hue="vecindad-size", palette=["r", "g","c","y"],
            data=mem_size)

plt.savefig("graficos/vecindad-size-ralo-2-ncuadrado.svg")

# %%
mem_size = df_resultados.copy();
plt.figure(figsize=(10, 7))
sns.lineplot(x="rango-n", y="tiempo",
            hue="vecindad-size", palette=["r", "g","b"],
            data=mem_size)


plt.savefig("graficos/tiempo-vecindad-size-ralo-2-ncuadrado.svg")

# %%
df_resultados = pd.read_csv("resultados/resultados-max-it-denso.csv");
df_resultados
# Out:
#    metodo   n    mG     mH  impacto       tiempo     error  max-it  rango-n
# 0     MH2  20    73   47.0     21.0     0.468442  0.553191       0       20
# 1     MH2  31   206   61.0     24.0     0.929141  0.606557       0       30
# 2     MH2  63  1141   14.0     12.0     2.659320  0.142857       0       60
# 3     MH2  34   234  169.0     42.0     2.584320  0.751479       0       30
# 4     MH2  42   429  246.0     58.0     4.523810  0.764228       0       40
# ..    ...  ..   ...    ...      ...          ...       ...     ...      ...
# 95    MH2  47   466  311.0     75.6   225.182000  0.756913       1       40
# 96    MH2  40   443  169.0     42.2   137.337000  0.750296       1       40
# 97    MH2  59   831  513.0    103.8   631.301000  0.797661       1       50
# 98    MH2  68  1204  422.0     96.2  1078.420000  0.772038       1       60
# 99    MH2  32   271   98.0     32.0    53.334600  0.673469       1       30
#
# [100 rows x 9 columns]

# %%
mem_size = df_resultados.copy();
plt.figure(figsize=(10, 7))
sns.boxplot(x="rango-n", y="error",
            hue="max-it", palette=["r", "g","c","y"],
            data=mem_size)

plt.savefig("graficos/max-it-denso.svg")

# %%
df_resultados = pd.read_csv("resultados/resultados-max-it-ralo.csv");
df_resultados
# Out:
#     metodo   n  mG      mH  impacto       tiempo     error  max-it  rango-n
# 0      MH2  34  24   294.0    158.0     2.177540  0.462585       0       30
# 1      MH2  25  13    53.0     37.0     0.363828  0.301887       0       20
# 2      MH2  39  20   133.0     83.0     1.314650  0.375940       0       30
# 3      MH2  60  12   698.0    529.0     8.125020  0.242120       0       60
# 4      MH2  51  17   143.0    104.0     2.961050  0.272727       0       50
# ..     ...  ..  ..     ...      ...          ...       ...     ...      ...
# 145    MH2  50  29   109.0     77.0   173.588000  0.293578       2       50
# 146    MH2  37  31   238.0    130.0   139.754000  0.453782       2       30
# 147    MH2  29  27   115.0     62.0    50.928600  0.460870       2       20
# 148    MH2  68  25   900.0    597.0  2277.700000  0.336667       2       60
# 149    MH2  64  40  1128.0    614.2  3335.710000  0.455496       2       60
#
# [150 rows x 9 columns]

# %%
mem_size = df_resultados.copy();
plt.figure(figsize=(10, 7))
sns.boxplot(x="rango-n", y="error",
            hue="max-it", palette=["r", "g","c","y"],
            data=mem_size)

plt.savefig("graficos/max-it-ralo.svg")

# %%
mem_size = df_resultados.copy();
plt.figure(figsize=(10, 7))
sns.lineplot(x="rango-n", y="tiempo",
            hue="max-it", palette=["r", "g","b"],
            data=mem_size)

plt.savefig("graficos/tiempo-max-it-ralo.svg")

# %%
df_resultados = pd.read_csv("resultados/resultados-max-it-denso.csv");
df_resultados
# Out:
#    metodo   n    mG     mH  impacto       tiempo     error  max-it  rango-n
# 0     MH2  20    73   47.0     21.0     0.468442  0.553191       0       20
# 1     MH2  31   206   61.0     24.0     0.929141  0.606557       0       30
# 2     MH2  63  1141   14.0     12.0     2.659320  0.142857       0       60
# 3     MH2  34   234  169.0     42.0     2.584320  0.751479       0       30
# 4     MH2  42   429  246.0     58.0     4.523810  0.764228       0       40
# ..    ...  ..   ...    ...      ...          ...       ...     ...      ...
# 95    MH2  47   466  311.0     75.6   225.182000  0.756913       1       40
# 96    MH2  40   443  169.0     42.2   137.337000  0.750296       1       40
# 97    MH2  59   831  513.0    103.8   631.301000  0.797661       1       50
# 98    MH2  68  1204  422.0     96.2  1078.420000  0.772038       1       60
# 99    MH2  32   271   98.0     32.0    53.334600  0.673469       1       30
#
# [100 rows x 9 columns]

# %%
mem_size = df_resultados.copy();
plt.figure(figsize=(10, 7))
sns.boxplot(x="rango-n", y="error",
            hue="max-it", palette=["r", "g","c","y"],
            data=mem_size)

plt.savefig("graficos/max-it-denso.svg")

# %%
mem_size = df_resultados.copy();
plt.figure(figsize=(10, 7))
sns.lineplot(x="rango-n", y="tiempo",
            hue="max-it", palette=["r", "g"],
            data=mem_size)

plt.savefig("graficos/tiempo-max-it-denso.svg")

# %%
df_resultados = pd.read_csv("resultados/resultados-golosasVsMeta2.csv");
df_resultados
# Out:
#    metodo   n   mG      mH  impacto       tiempo     error algoritmo
# 0      H1  18   41   54\n2     12.0     0.127096  0.555556        H1
# 1      H1  22   77   58\n1     16.0     0.197997  0.384615        H1
# 2      H1  16   35   43\n7     18.0     0.081372  0.100000        H1
# 3      H1  14   29   25\n2      9.0     0.069030  0.250000        H1
# 4      H1  26   98  103\n4     26.0     0.218306  0.315789        H1
# 5      H1  24   79   72\n2     24.0     0.205201  0.272727        H1
# 6      H1  10   20    5\n5      3.0     0.037630  0.000000        H1
# 7      H1  30  137  128\n5     33.0     0.331028  0.297872        H1
# 8      H1  12   16   26\n1     11.0     0.043713  0.312500        H1
# 9      H1   6    7    2\n4      1.0     0.019447  0.000000        H1
# 10     H1   8    8    8\n4      6.0     0.026301  0.000000        H1
# 11     H1  20   57   51\n3     18.0     0.225104  0.280000        H1
# 12     H1  28  106  117\n1     32.0     0.414233  0.333333        H1
# ...

# %%
mem_size = df_resultados.copy();
plt.figure(figsize=(10, 7))
sns.scatterplot(x="error", y="tiempo",
            hue="algoritmo", palette=["r", "g","c","y"],
            data=mem_size)

plt.savefig("graficos/comparacionGolosasMeta2.svg")

# %%
df_resultados = pd.read_csv("resultados/resultados-golosasVsMeta2.csv");
df_resultados
# Out:
#     metodo   n  mG      mH  impacto       tiempo     error algoritmo  rango-n
# 0       H1  34  24   294.0    120.0     0.199029  0.591837        H1       30
# 1       H1  25  13    53.0     27.0     0.079493  0.490566        H1       20
# 2       H1  39  20   133.0     61.0     0.137345  0.541353        H1       30
# 3       H1  60  12   698.0    486.0     0.283235  0.303725        H1       60
# 4       H1  51  17   143.0     71.0     0.135684  0.503497        H1       50
# ..     ...  ..  ..     ...      ...          ...       ...       ...      ...
# 195    MH2  50  29   109.0     77.0    80.186000  0.293578       MH2       50
# 196    MH2  37  31   238.0    126.0    69.805400  0.470588       MH2       30
# 197    MH2  29  27   115.0     62.0    24.672200  0.460870       MH2       20
# 198    MH2  68  25   900.0    593.0  1119.650000  0.341111       MH2       60
# 199    MH2  64  40  1128.0    607.8  1717.600000  0.461170       MH2       60
#
# [200 rows x 9 columns]

# %%
mem_size = df_resultados.copy();
plt.figure(figsize=(10, 7))
sns.boxplot(x="rango-n", y="error",
            hue="algoritmo", palette=["r", "g","c","y"],
            data=mem_size)

plt.savefig("graficos/golosasVsMetasInstanciasNuevas.svg")

# %%
for i in range (0,25):
    memsize = 4*i
    df_resultados = pd.read_csv(f"resultados/Caos/resultados-impactoVsIteracionConAzar-{memsize}.csv");
    plt.figure(figsize=(16, 6))
    fig = sns.lineplot(data=df_resultados, x='iteracion', y='impacto',palette='bright',ci=None)
    plt.savefig(f"graficos/Caos/impactoVsIt-{memsize}.svg")
# Out:
# <ipython-input-4-6b9b5f334a25>:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(16, 6))
